# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("../data/job_market_2025.csv")
df
# Out:
#                      job_title seniority_level   status      company  \
# 0               data scientist          senior   hybrid  company_003
# 1               data scientist            lead   hybrid  company_005
# 2               data scientist          senior  on-site  company_007
# 3               data scientist          senior   hybrid  company_008
# 4               data scientist             NaN  on-site  company_009
# ..                         ...             ...      ...          ...
# 939             data scientist          senior      NaN  company_171
# 940  machine learning engineer          senior      NaN  company_134
# 941             data scientist        midlevel  on-site  company_395
# 942             data scientist        midlevel  on-site  company_395
# 943             data scientist          senior  on-site  company_844
#
#                                               location    post_date  \
# 0                               Grapevine, TX . Hybrid  17 days ago
# 1                              Fort Worth, TX . Hybrid  15 days ago
# 2    Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3    Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                              On-site   3 days ago
# ..                                                 ...          ...
# 939                        Bengaluru, Karnataka, India    a day ago
# 940                     Melbourne, Victoria, Australia  a month ago
# 941                                         McLean, VA  11 days ago
# 942                                       New York, NY  17 days ago
# 943                                      San Diego, CA   8 days ago
#
#                headquarter       industry ownership company_size   revenue  \
# 0      Bentonville, AR, US         Retail    Public     €352.44B    Public
# 1          Detroit, MI, US  Manufacturing    Public      155,030   €51.10B
# 2     Redwood City, CA, US     Technology    Public       25,930   €33.80B
# 3         San Jose, CA, US     Technology    Public       34,690   €81.71B
# 4         Stamford, CT, US        Finance   Private        1,800   Private
# ..                     ...            ...       ...          ...       ...
# 939         Armonk, NY, US     Technology    Public      524,598  €120.29B
# 940        Seattle, WA, US         Retail    Public      865,456  €838.78B
# 941         McLean, VA, US         Retail    Public       55,150   €36.29B
# 942         McLean, VA, US         Retail    Public       55,110   €36.34B
# 943  Mountain View, CA, US     Technology    Public       17,040   €95.22B
#
#                   salary                                             skills
# 0    €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1               €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2     €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3    €112,797 - €194,402                             ['sql', 'r', 'python']
# 4    €114,172 - €228,337                                                 []
# ..                   ...                                                ...
# 939    €33,288 - €53,080  ['pytorch', 'python', 'sql', 'machine learning...
# 940              €64,290                     ['amazon', 'machine learning']
# 941  €145,904 - €166,510  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 942  €159,149 - €181,595  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 943  €195,486 - €201,926  ['r', 'python', 'scala', 'sql', 'machine learn...
#
# [944 rows x 13 columns]

# %%
df.to_csv("../cleaned_data/cleaned_job_market_2025.csv", index=False)
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        941 non-null    object
#  1   seniority_level  884 non-null    object
#  2   status           688 non-null    object
#  3   company          944 non-null    object
#  4   location         942 non-null    object
#  5   post_date        944 non-null    object
#  6   headquarter      944 non-null    object
#  7   industry         944 non-null    object
#  8   ownership        897 non-null    object
#  9   company_size     944 non-null    object
#  10  revenue          929 non-null    object
#  11  salary           944 non-null    object
#  12  skills           944 non-null    object
#  13  salary_numeric   944 non-null    float64
#  14  days_ago         756 non-null    float64
# dtypes: float64(2), object(13)
# memory usage: 110.8+ KB

# %% [markdown]
# #  Data cleaning

# %%
df.head()
# Out:
#         job_title seniority_level   status      company  \
# 0  data scientist          senior   hybrid  company_003
# 1  data scientist            lead   hybrid  company_005
# 2  data scientist          senior  on-site  company_007
# 3  data scientist          senior   hybrid  company_008
# 4  data scientist             NaN  on-site  company_009
#
#                                             location    post_date  \
# 0                             Grapevine, TX . Hybrid  17 days ago
# 1                            Fort Worth, TX . Hybrid  15 days ago
# 2  Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3  Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                            On-site   3 days ago
#
#             headquarter       industry ownership company_size  revenue  \
# 0   Bentonville, AR, US         Retail    Public     €352.44B   Public
# 1       Detroit, MI, US  Manufacturing    Public      155,030  €51.10B
# 2  Redwood City, CA, US     Technology    Public       25,930  €33.80B
# 3      San Jose, CA, US     Technology    Public       34,690  €81.71B
# 4      Stamford, CT, US        Finance   Private        1,800  Private
#
#                 salary                                             skills
# 0  €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1             €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2   €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3  €112,797 - €194,402                             ['sql', 'r', 'python']
# 4  €114,172 - €228,337                                                 []

# %%
df.shape
# Out:
# (944, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        941 non-null    object
#  1   seniority_level  884 non-null    object
#  2   status           688 non-null    object
#  3   company          944 non-null    object
#  4   location         942 non-null    object
#  5   post_date        944 non-null    object
#  6   headquarter      944 non-null    object
#  7   industry         944 non-null    object
#  8   ownership        897 non-null    object
#  9   company_size     944 non-null    object
#  10  revenue          929 non-null    object
#  11  salary           944 non-null    object
#  12  skills           944 non-null    object
# dtypes: object(13)
# memory usage: 96.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        941 non-null    object
#  1   seniority_level  884 non-null    object
#  2   status           688 non-null    object
#  3   company          944 non-null    object
#  4   location         942 non-null    object
#  5   post_date        944 non-null    object
#  6   headquarter      944 non-null    object
#  7   industry         944 non-null    object
#  8   ownership        897 non-null    object
#  9   company_size     944 non-null    object
#  10  revenue          929 non-null    object
#  11  salary           944 non-null    object
#  12  skills           944 non-null    object
# dtypes: object(13)
# memory usage: 96.0+ KB

# %%
df.columns
# Out:
# Index(['job_title', 'seniority_level', 'status', 'company', 'location',
#        'post_date', 'headquarter', 'industry', 'ownership', 'company_size',
#        'revenue', 'salary', 'skills'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# job_title            3
# seniority_level     60
# status             256
# company              0
# location             2
# post_date            0
# headquarter          0
# industry             0
# ownership           47
# company_size         0
# revenue             15
# salary               0
# skills               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['job_title', 'seniority_level', 'status', 'company', 'location',
#        'post_date', 'headquarter', 'industry', 'ownership', 'company_size',
#        'revenue', 'salary', 'skills'],
#       dtype='object')

# %%
# Remove null job titles
df = df.dropna(subset=['job_title']).copy()

# Fill missing values
df['seniority_level'] = df['seniority_level'].fillna('Not Specified')

df['status'] = df['status'].fillna('Unknown')

df['location'] = df['location'].fillna('Unknown')

df['ownership'] = df['ownership'].fillna('Unknown')

df['revenue'] = df['revenue'].fillna('Not Mentioned')

# Create days_ago column
df['days_ago'] = df['post_date'].str.extract(r'(\d+)')

# Convert to numeric
df['days_ago'] = pd.to_numeric(
    df['days_ago'],
    errors='coerce'
)

# Fill missing values
df['days_ago'] = df['days_ago'].fillna(0)

# Convert to integer
df['days_ago'] = df['days_ago'].astype(int)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 941 entries, 0 to 943
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        941 non-null    object
#  1   seniority_level  941 non-null    object
#  2   status           941 non-null    object
#  3   company          941 non-null    object
#  4   location         941 non-null    object
#  5   post_date        941 non-null    object
#  6   headquarter      941 non-null    object
#  7   industry         941 non-null    object
#  8   ownership        941 non-null    object
#  9   company_size     941 non-null    object
#  10  revenue          941 non-null    object
#  11  salary           941 non-null    object
#  12  skills           941 non-null    object
#  13  salary_numeric   941 non-null    float64
#  14  days_ago         941 non-null    int64
# dtypes: float64(1), int64(1), object(13)
# memory usage: 117.6+ KB
# C:\Users\gayat\AppData\Local\Temp\ipykernel_12856\3018397666.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['seniority_level'] = df['seniority_level'].fillna('Not Specified')
# C:\Users\gayat\AppData\Local\Temp\ipykernel_12856\3018397666.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['status'] = df['status'].fillna('Unknown')
# C:\Users\gayat\AppData\Local\Temp\ipykernel_12856\3018397666.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location'] = df['location'].fillna('Unknown')
# C:\Users\gayat\AppData\Local\Temp\ipykernel_12856\3018397666.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ownership'] = df['ownership'].fillna('Unknown')
# C:\Users\gayat\AppData\Local\Temp\ipykernel_12856\3018397666.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['revenue'] = df['revenue'].fillna('Not Mentioned')
# C:\Users\gayat\AppData\Local\Temp\ipykernel_12856\3018397666.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_ago'] = df['post_date'].str.extract(r'(\d+)')
# C:\Users\gayat\AppData\Local\Temp\ipykernel_12856\3018397666.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_ago'] = pd.to_numeric(
# C:\Users\gayat\AppData\Local\Temp\ipykernel_12856\3018397666.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_ago'] = df['days_ago'].fillna(0)
# C:\Users\gayat\AppData\Local\Temp\ipykernel_12856\3018397666.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_ago'] = df['days_ago'].astype(int)

# %% [markdown]
# # Basic Analysis

# %%
df['job_title'].value_counts().head(10)
# Out:
# job_title
# data scientist               856
# machine learning engineer     80
# data engineer                  4
# data analyst                   1
# Name: count, dtype: int64

# %%
df['location'].value_counts().head(10)
# Out:
# location
# Bengaluru, Karnataka, India             52
# Fully Remote                            35
# New York, NY                            22
# United States                           22
# On-site                                 18
# San Francisco, CA                       17
# Mountain View, CA                       17
# Sunnyvale, CA                           13
# Bengaluru, Karnataka, India . Hybrid    12
# Hybrid                                  12
# Name: count, dtype: int64

# %%
df['skills'].head()
# Out:
# 0    ['spark', 'r', 'python', 'scala', 'machine lea...
# 1    ['spark', 'r', 'python', 'sql', 'machine learn...
# 2    ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3                               ['sql', 'r', 'python']
# 4                                                   []
# Name: skills, dtype: object

# %%
df = df.dropna(subset=['job_title'])
df
# Out:
#                      job_title seniority_level   status      company  \
# 0               data scientist          senior   hybrid  company_003
# 1               data scientist            lead   hybrid  company_005
# 2               data scientist          senior  on-site  company_007
# 3               data scientist          senior   hybrid  company_008
# 4               data scientist   Not Specified  on-site  company_009
# ..                         ...             ...      ...          ...
# 939             data scientist          senior      NaN  company_171
# 940  machine learning engineer          senior      NaN  company_134
# 941             data scientist        midlevel  on-site  company_395
# 942             data scientist        midlevel  on-site  company_395
# 943             data scientist          senior  on-site  company_844
#
#                                               location    post_date  \
# 0                               Grapevine, TX . Hybrid  17 days ago
# 1                              Fort Worth, TX . Hybrid  15 days ago
# 2    Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3    Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                              On-site   3 days ago
# ..                                                 ...          ...
# 939                        Bengaluru, Karnataka, India    a day ago
# 940                     Melbourne, Victoria, Australia  a month ago
# 941                                         McLean, VA  11 days ago
# 942                                       New York, NY  17 days ago
# 943                                      San Diego, CA   8 days ago
#
#                headquarter       industry ownership company_size   revenue  \
# 0      Bentonville, AR, US         Retail    Public     €352.44B    Public
# 1          Detroit, MI, US  Manufacturing    Public      155,030   €51.10B
# 2     Redwood City, CA, US     Technology    Public       25,930   €33.80B
# 3         San Jose, CA, US     Technology    Public       34,690   €81.71B
# 4         Stamford, CT, US        Finance   Private        1,800   Private
# ..                     ...            ...       ...          ...       ...
# 939         Armonk, NY, US     Technology    Public      524,598  €120.29B
# 940        Seattle, WA, US         Retail    Public      865,456  €838.78B
# 941         McLean, VA, US         Retail    Public       55,150   €36.29B
# 942         McLean, VA, US         Retail    Public       55,110   €36.34B
# 943  Mountain View, CA, US     Technology    Public       17,040   €95.22B
#
#                   salary                                             skills
# 0    €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1               €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2     €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3    €112,797 - €194,402                             ['sql', 'r', 'python']
# 4    €114,172 - €228,337                                                 []
# ..                   ...                                                ...
# 939    €33,288 - €53,080  ['pytorch', 'python', 'sql', 'machine learning...
# 940              €64,290                     ['amazon', 'machine learning']
# 941  €145,904 - €166,510  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 942  €159,149 - €181,595  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 943  €195,486 - €201,926  ['r', 'python', 'scala', 'sql', 'machine learn...
#
# [941 rows x 13 columns]

# %%
df['seniority_level'] = df['seniority_level'].fillna('Not Specified')
df
# Out:
#                      job_title seniority_level   status      company  \
# 0               data scientist          senior   hybrid  company_003
# 1               data scientist            lead   hybrid  company_005
# 2               data scientist          senior  on-site  company_007
# 3               data scientist          senior   hybrid  company_008
# 4               data scientist   Not Specified  on-site  company_009
# ..                         ...             ...      ...          ...
# 939             data scientist          senior      NaN  company_171
# 940  machine learning engineer          senior      NaN  company_134
# 941             data scientist        midlevel  on-site  company_395
# 942             data scientist        midlevel  on-site  company_395
# 943             data scientist          senior  on-site  company_844
#
#                                               location    post_date  \
# 0                               Grapevine, TX . Hybrid  17 days ago
# 1                              Fort Worth, TX . Hybrid  15 days ago
# 2    Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3    Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                              On-site   3 days ago
# ..                                                 ...          ...
# 939                        Bengaluru, Karnataka, India    a day ago
# 940                     Melbourne, Victoria, Australia  a month ago
# 941                                         McLean, VA  11 days ago
# 942                                       New York, NY  17 days ago
# 943                                      San Diego, CA   8 days ago
#
#                headquarter       industry ownership company_size   revenue  \
# 0      Bentonville, AR, US         Retail    Public     €352.44B    Public
# 1          Detroit, MI, US  Manufacturing    Public      155,030   €51.10B
# 2     Redwood City, CA, US     Technology    Public       25,930   €33.80B
# 3         San Jose, CA, US     Technology    Public       34,690   €81.71B
# 4         Stamford, CT, US        Finance   Private        1,800   Private
# ..                     ...            ...       ...          ...       ...
# 939         Armonk, NY, US     Technology    Public      524,598  €120.29B
# 940        Seattle, WA, US         Retail    Public      865,456  €838.78B
# 941         McLean, VA, US         Retail    Public       55,150   €36.29B
# 942         McLean, VA, US         Retail    Public       55,110   €36.34B
# 943  Mountain View, CA, US     Technology    Public       17,040   €95.22B
#
#                   salary                                             skills
# 0    €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1               €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2     €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3    €112,797 - €194,402                             ['sql', 'r', 'python']
# 4    €114,172 - €228,337                                                 []
# ..                   ...                                                ...
# 939    €33,288 - €53,080  ['pytorch', 'python', 'sql', 'machine learning...
# 940              €64,290                     ['amazon', 'machine learning']
# 941  €145,904 - €166,510  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 942  €159,149 - €181,595  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 943  €195,486 - €201,926  ['r', 'python', 'scala', 'sql', 'machine learn...
#
# [941 rows x 13 columns]

# %%
df['status'] = df['status'].fillna('Unknown')
df
# Out:
#                      job_title seniority_level   status      company  \
# 0               data scientist          senior   hybrid  company_003
# 1               data scientist            lead   hybrid  company_005
# 2               data scientist          senior  on-site  company_007
# 3               data scientist          senior   hybrid  company_008
# 4               data scientist   Not Specified  on-site  company_009
# ..                         ...             ...      ...          ...
# 939             data scientist          senior  Unknown  company_171
# 940  machine learning engineer          senior  Unknown  company_134
# 941             data scientist        midlevel  on-site  company_395
# 942             data scientist        midlevel  on-site  company_395
# 943             data scientist          senior  on-site  company_844
#
#                                               location    post_date  \
# 0                               Grapevine, TX . Hybrid  17 days ago
# 1                              Fort Worth, TX . Hybrid  15 days ago
# 2    Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3    Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                              On-site   3 days ago
# ..                                                 ...          ...
# 939                        Bengaluru, Karnataka, India    a day ago
# 940                     Melbourne, Victoria, Australia  a month ago
# 941                                         McLean, VA  11 days ago
# 942                                       New York, NY  17 days ago
# 943                                      San Diego, CA   8 days ago
#
#                headquarter       industry ownership company_size   revenue  \
# 0      Bentonville, AR, US         Retail    Public     €352.44B    Public
# 1          Detroit, MI, US  Manufacturing    Public      155,030   €51.10B
# 2     Redwood City, CA, US     Technology    Public       25,930   €33.80B
# 3         San Jose, CA, US     Technology    Public       34,690   €81.71B
# 4         Stamford, CT, US        Finance   Private        1,800   Private
# ..                     ...            ...       ...          ...       ...
# 939         Armonk, NY, US     Technology    Public      524,598  €120.29B
# 940        Seattle, WA, US         Retail    Public      865,456  €838.78B
# 941         McLean, VA, US         Retail    Public       55,150   €36.29B
# 942         McLean, VA, US         Retail    Public       55,110   €36.34B
# 943  Mountain View, CA, US     Technology    Public       17,040   €95.22B
#
#                   salary                                             skills
# 0    €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1               €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2     €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3    €112,797 - €194,402                             ['sql', 'r', 'python']
# 4    €114,172 - €228,337                                                 []
# ..                   ...                                                ...
# 939    €33,288 - €53,080  ['pytorch', 'python', 'sql', 'machine learning...
# 940              €64,290                     ['amazon', 'machine learning']
# 941  €145,904 - €166,510  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 942  €159,149 - €181,595  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 943  €195,486 - €201,926  ['r', 'python', 'scala', 'sql', 'machine learn...
#
# [941 rows x 13 columns]

# %%
df['location'] = df['location'].fillna('Unknown')
df
# Out:
#                      job_title seniority_level   status      company  \
# 0               data scientist          senior   hybrid  company_003
# 1               data scientist            lead   hybrid  company_005
# 2               data scientist          senior  on-site  company_007
# 3               data scientist          senior   hybrid  company_008
# 4               data scientist   Not Specified  on-site  company_009
# ..                         ...             ...      ...          ...
# 939             data scientist          senior  Unknown  company_171
# 940  machine learning engineer          senior  Unknown  company_134
# 941             data scientist        midlevel  on-site  company_395
# 942             data scientist        midlevel  on-site  company_395
# 943             data scientist          senior  on-site  company_844
#
#                                               location    post_date  \
# 0                               Grapevine, TX . Hybrid  17 days ago
# 1                              Fort Worth, TX . Hybrid  15 days ago
# 2    Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3    Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                              On-site   3 days ago
# ..                                                 ...          ...
# 939                        Bengaluru, Karnataka, India    a day ago
# 940                     Melbourne, Victoria, Australia  a month ago
# 941                                         McLean, VA  11 days ago
# 942                                       New York, NY  17 days ago
# 943                                      San Diego, CA   8 days ago
#
#                headquarter       industry ownership company_size   revenue  \
# 0      Bentonville, AR, US         Retail    Public     €352.44B    Public
# 1          Detroit, MI, US  Manufacturing    Public      155,030   €51.10B
# 2     Redwood City, CA, US     Technology    Public       25,930   €33.80B
# 3         San Jose, CA, US     Technology    Public       34,690   €81.71B
# 4         Stamford, CT, US        Finance   Private        1,800   Private
# ..                     ...            ...       ...          ...       ...
# 939         Armonk, NY, US     Technology    Public      524,598  €120.29B
# 940        Seattle, WA, US         Retail    Public      865,456  €838.78B
# 941         McLean, VA, US         Retail    Public       55,150   €36.29B
# 942         McLean, VA, US         Retail    Public       55,110   €36.34B
# 943  Mountain View, CA, US     Technology    Public       17,040   €95.22B
#
#                   salary                                             skills
# 0    €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1               €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2     €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3    €112,797 - €194,402                             ['sql', 'r', 'python']
# 4    €114,172 - €228,337                                                 []
# ..                   ...                                                ...
# 939    €33,288 - €53,080  ['pytorch', 'python', 'sql', 'machine learning...
# 940              €64,290                     ['amazon', 'machine learning']
# 941  €145,904 - €166,510  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 942  €159,149 - €181,595  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 943  €195,486 - €201,926  ['r', 'python', 'scala', 'sql', 'machine learn...
#
# [941 rows x 13 columns]

# %%
df['ownership'] = df['ownership'].fillna('Unknown')
df
# Out:
#                      job_title seniority_level   status      company  \
# 0               data scientist          senior   hybrid  company_003
# 1               data scientist            lead   hybrid  company_005
# 2               data scientist          senior  on-site  company_007
# 3               data scientist          senior   hybrid  company_008
# 4               data scientist   Not Specified  on-site  company_009
# ..                         ...             ...      ...          ...
# 939             data scientist          senior  Unknown  company_171
# 940  machine learning engineer          senior  Unknown  company_134
# 941             data scientist        midlevel  on-site  company_395
# 942             data scientist        midlevel  on-site  company_395
# 943             data scientist          senior  on-site  company_844
#
#                                               location    post_date  \
# 0                               Grapevine, TX . Hybrid  17 days ago
# 1                              Fort Worth, TX . Hybrid  15 days ago
# 2    Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3    Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                              On-site   3 days ago
# ..                                                 ...          ...
# 939                        Bengaluru, Karnataka, India    a day ago
# 940                     Melbourne, Victoria, Australia  a month ago
# 941                                         McLean, VA  11 days ago
# 942                                       New York, NY  17 days ago
# 943                                      San Diego, CA   8 days ago
#
#                headquarter       industry ownership company_size   revenue  \
# 0      Bentonville, AR, US         Retail    Public     €352.44B    Public
# 1          Detroit, MI, US  Manufacturing    Public      155,030   €51.10B
# 2     Redwood City, CA, US     Technology    Public       25,930   €33.80B
# 3         San Jose, CA, US     Technology    Public       34,690   €81.71B
# 4         Stamford, CT, US        Finance   Private        1,800   Private
# ..                     ...            ...       ...          ...       ...
# 939         Armonk, NY, US     Technology    Public      524,598  €120.29B
# 940        Seattle, WA, US         Retail    Public      865,456  €838.78B
# 941         McLean, VA, US         Retail    Public       55,150   €36.29B
# 942         McLean, VA, US         Retail    Public       55,110   €36.34B
# 943  Mountain View, CA, US     Technology    Public       17,040   €95.22B
#
#                   salary                                             skills
# 0    €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1               €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2     €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3    €112,797 - €194,402                             ['sql', 'r', 'python']
# 4    €114,172 - €228,337                                                 []
# ..                   ...                                                ...
# 939    €33,288 - €53,080  ['pytorch', 'python', 'sql', 'machine learning...
# 940              €64,290                     ['amazon', 'machine learning']
# 941  €145,904 - €166,510  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 942  €159,149 - €181,595  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 943  €195,486 - €201,926  ['r', 'python', 'scala', 'sql', 'machine learn...
#
# [941 rows x 13 columns]

# %%
df['revenue'] = df['revenue'].fillna('Not Mentioned')
df
# Out:
#                      job_title seniority_level   status      company  \
# 0               data scientist          senior   hybrid  company_003
# 1               data scientist            lead   hybrid  company_005
# 2               data scientist          senior  on-site  company_007
# 3               data scientist          senior   hybrid  company_008
# 4               data scientist   Not Specified  on-site  company_009
# ..                         ...             ...      ...          ...
# 939             data scientist          senior  Unknown  company_171
# 940  machine learning engineer          senior  Unknown  company_134
# 941             data scientist        midlevel  on-site  company_395
# 942             data scientist        midlevel  on-site  company_395
# 943             data scientist          senior  on-site  company_844
#
#                                               location    post_date  \
# 0                               Grapevine, TX . Hybrid  17 days ago
# 1                              Fort Worth, TX . Hybrid  15 days ago
# 2    Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3    Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                              On-site   3 days ago
# ..                                                 ...          ...
# 939                        Bengaluru, Karnataka, India    a day ago
# 940                     Melbourne, Victoria, Australia  a month ago
# 941                                         McLean, VA  11 days ago
# 942                                       New York, NY  17 days ago
# 943                                      San Diego, CA   8 days ago
#
#                headquarter       industry ownership company_size   revenue  \
# 0      Bentonville, AR, US         Retail    Public     €352.44B    Public
# 1          Detroit, MI, US  Manufacturing    Public      155,030   €51.10B
# 2     Redwood City, CA, US     Technology    Public       25,930   €33.80B
# 3         San Jose, CA, US     Technology    Public       34,690   €81.71B
# 4         Stamford, CT, US        Finance   Private        1,800   Private
# ..                     ...            ...       ...          ...       ...
# 939         Armonk, NY, US     Technology    Public      524,598  €120.29B
# 940        Seattle, WA, US         Retail    Public      865,456  €838.78B
# 941         McLean, VA, US         Retail    Public       55,150   €36.29B
# 942         McLean, VA, US         Retail    Public       55,110   €36.34B
# 943  Mountain View, CA, US     Technology    Public       17,040   €95.22B
#
#                   salary                                             skills
# 0    €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1               €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2     €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3    €112,797 - €194,402                             ['sql', 'r', 'python']
# 4    €114,172 - €228,337                                                 []
# ..                   ...                                                ...
# 939    €33,288 - €53,080  ['pytorch', 'python', 'sql', 'machine learning...
# 940              €64,290                     ['amazon', 'machine learning']
# 941  €145,904 - €166,510  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 942  €159,149 - €181,595  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 943  €195,486 - €201,926  ['r', 'python', 'scala', 'sql', 'machine learn...
#
# [941 rows x 13 columns]

# %% [markdown]
# # Convert Date

# %%
# Create Days Column
df['days_ago'] = df['post_date'].str.extract(r'(\d+)')
df['days_ago'] = pd.to_numeric(df['days_ago'], errors='coerce')
df['days_ago'] = df['days_ago'].fillna(0).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 941 entries, 0 to 943
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        941 non-null    object
#  1   seniority_level  941 non-null    object
#  2   status           941 non-null    object
#  3   company          941 non-null    object
#  4   location         941 non-null    object
#  5   post_date        941 non-null    object
#  6   headquarter      941 non-null    object
#  7   industry         941 non-null    object
#  8   ownership        941 non-null    object
#  9   company_size     941 non-null    object
#  10  revenue          941 non-null    object
#  11  salary           941 non-null    object
#  12  skills           941 non-null    object
#  13  days_ago         941 non-null    int64
# dtypes: int64(1), object(13)
# memory usage: 110.3+ KB

# %%
df[['post_date', 'days_ago']].head()
# Out:
#      post_date  days_ago
# 0  17 days ago        17
# 1  15 days ago        15
# 2  a month ago         0
# 3   8 days ago         8
# 4   3 days ago         3

# %%
df[['post_date', 'days_ago']].head(10)
# Out:
#       post_date  days_ago
# 0   17 days ago        17
# 1   15 days ago        15
# 2   a month ago         0
# 3    8 days ago         8
# 4    3 days ago         3
# 5  3 months ago         3
# 6   15 days ago        15
# 7    9 days ago         9
# 8    6 days ago         6
# 9     a day ago         0

# %%
# Recent Job Trends
recent_jobs = df[df['days_ago'] <= 7]

recent_jobs.shape
# Out:
# (534, 14)

# %% [markdown]
# # KPI Analysis

# %% [markdown]
# # BIVARIATE ANALYSIS
# (Two variables analysis)

# %%
# Average Salary by Seniority
df.groupby('seniority_level')['salary_numeric'].mean().sort_values(ascending=False)
# Out:
# seniority_level
# lead        150339.099138
# senior      135549.150000
# midlevel    100323.601770
# junior       87939.740000
# Name: salary_numeric, dtype: float64

# %%
# Jobs by Industry
df.groupby('industry')['job_title'].count().sort_values(ascending=False).head(10)
# Out:
# industry
# Technology       580
# Finance          127
# Retail           110
# Healthcare        83
# Education         18
# Energy            12
# Manufacturing      7
# Logistics          4
# Name: job_title, dtype: int64

# %%
# Company Size vs Job Count
df.groupby('company_size')['job_title'].count().sort_values(ascending=False)
# Out:
# company_size
# 900         17
# 45          15
# 180         15
# Private     15
# €354.99B    14
#             ..
# 26,630       1
# 26,070       1
# 26,060       1
# 52,380       0
# 16,011       0
# Name: job_title, Length: 510, dtype: int64

# %%
# Location vs Jobs
df.groupby('location')['job_title'].count().sort_values(ascending=False).head(10)
# Out:
# location
# Bengaluru, Karnataka, India             52
# Fully Remote                            35
# New York, NY                            22
# United States                           22
# On-site                                 18
# San Francisco, CA                       17
# Mountain View, CA                       17
# Sunnyvale, CA                           13
# Hybrid                                  12
# Bengaluru, Karnataka, India . Hybrid    12
# Name: job_title, dtype: int64

# %% [markdown]
# # UNIVARIATE ANALYSIS
# (One variable analysis)

# %%
# 1.Total Job Postings

total_jobs = df.shape[0]

print("Total Job Postings:", total_jobs)
# Out:
# Total Job Postings: 941

# %%
# 2. Top Job Roles

top_roles = df['job_title'].value_counts().head(10)

top_roles
# Out:
# job_title
# data scientist               856
# machine learning engineer     80
# data engineer                  4
# data analyst                   1
# Name: count, dtype: int64

# %%
# 3. Top Hiring Locations

top_locations = df['location'].value_counts().head(10)

top_locations
# Out:
# location
# Bengaluru, Karnataka, India             52
# Fully Remote                            35
# United States                           22
# New York, NY                            22
# On-site                                 18
# Mountain View, CA                       17
# San Francisco, CA                       17
# Sunnyvale, CA                           13
# Hybrid                                  12
# Bengaluru, Karnataka, India . Hybrid    12
# Name: count, dtype: int64

# %%
# 4. Most Demanded Skills

skills_series = df['skills'].str.split(',')

all_skills = skills_series.explode()
top_skills = all_skills.value_counts().head(10)

top_skills
# Out:
# skills
#  'machine learning'    428
#  'python'              398
#  'sql'                 307
#  'r'                   303
#  'python']             222
# []                     201
#  'aws'                 151
#  'tensorflow']         145
# ['sql'                 133
#  'deep learning'       110
# Name: count, dtype: int64

# %%
# 5. Most Hiring Companies

top_companies = df['company'].value_counts().head(10)

top_companies
# Out:
# company
# company_134    30
# company_003    24
# company_395    21
# company_941    21
# company_917    20
# company_244    20
# company_273    19
# company_844    18
# company_008    17
# company_983    13
# Name: count, dtype: int64

# %%
# 6. Seniority Level Distribution
df['seniority_level'].value_counts()
# Out:
# seniority_level
# senior           630
# lead             115
# midlevel         111
# Not Specified     60
# junior            25
# Name: count, dtype: int64

# %% [markdown]
# ## Create Charts

# %% [markdown]
# # UNIVARIATE ANALYSIS
# #(One variable analysis)

# %%
# Top Job Roles

plt.figure(figsize=(10,6))

top_roles.plot(kind='bar')

plt.title("Top 10 Job Roles")

plt.xlabel("Job Role")
plt.ylabel("Count")

plt.xticks(rotation=45)

plt.savefig("../charts/top_job_roles.png")

plt.show()

# %%
# Top Skills Chart

top_skills = df['skills'].str.split(',').explode().str.strip().value_counts().head(10)

plt.figure(figsize=(10,6))
top_skills.sort_values().plot(kind='barh')
plt.title("Top 10 Most Demanded Skills")
plt.xlabel("Job Count")
plt.ylabel("Skills")
plt.savefig("../charts/top_skills.png", bbox_inches="tight")
plt.show()

# %%
df['days_ago'] = df['post_date'].str.extract(r'(\d+)')
df['days_ago'] = pd.to_numeric(df['days_ago'], errors='coerce')
df.head()
# Out:
#         job_title seniority_level   status      company  \
# 0  data scientist          senior   hybrid  company_003
# 1  data scientist            lead   hybrid  company_005
# 2  data scientist          senior  on-site  company_007
# 3  data scientist          senior   hybrid  company_008
# 4  data scientist             NaN  on-site  company_009
#
#                                             location    post_date  \
# 0                             Grapevine, TX . Hybrid  17 days ago
# 1                            Fort Worth, TX . Hybrid  15 days ago
# 2  Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3  Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                            On-site   3 days ago
#
#             headquarter       industry ownership company_size  revenue  \
# 0   Bentonville, AR, US         Retail    Public     €352.44B   Public
# 1       Detroit, MI, US  Manufacturing    Public      155,030  €51.10B
# 2  Redwood City, CA, US     Technology    Public       25,930  €33.80B
# 3      San Jose, CA, US     Technology    Public       34,690  €81.71B
# 4      Stamford, CT, US        Finance   Private        1,800  Private
#
#                 salary                                             skills  \
# 0  €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1             €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2   €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3  €112,797 - €194,402                             ['sql', 'r', 'python']
# 4  €114,172 - €228,337                                                 []
#
#    salary_numeric  days_ago
# 0        150705.0      17.0
# 1        118733.0      15.0
# 2        127273.0       NaN
# 3        153599.5       8.0
# 4        171254.5       3.0

# %%
#  Job Posting Trend

jobs_by_day = df['days_ago'].value_counts().sort_index()

plt.figure(figsize=(10,5))

plt.plot(
    jobs_by_day.index,
    jobs_by_day.values,
    marker='o'
)

plt.title("Job Posting Trend by Days Ago")
plt.xlabel("Days Ago")
plt.ylabel("Number of Jobs")

plt.savefig("../charts/job_posting_trend.png", bbox_inches="tight")

plt.show()

# %%
# Seniority Level

seniority_count = df['seniority_level'].value_counts()

plt.figure(figsize=(7,7))
plt.pie(
    seniority_count,
    labels=seniority_count.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.title("Seniority Level Distribution")
plt.savefig("../charts/seniority_distribution.png", bbox_inches="tight")
plt.show()

# %%
# Top Locations

top_locations = df['location'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_locations.plot(kind='bar')
plt.title("Top 10 Hiring Locations")
plt.xlabel("Location")
plt.ylabel("Job Count")
plt.xticks(rotation=45, ha='right')
plt.savefig("../charts/top_locations.png", bbox_inches="tight")
plt.show()

# %%
# Top Companies

top_companies = df['company'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_companies.sort_values().plot(kind='barh')
plt.title("Top 10 Hiring Companies")
plt.xlabel("Job Count")
plt.ylabel("Company")
plt.savefig("../charts/top_companies.png", bbox_inches="tight")
plt.show()

# %%
# Industry Distribution

industry_count = df['industry'].value_counts()

top5 = industry_count.head(5)

others = pd.Series(
    {'Others': industry_count.iloc[5:].sum()}
)

final_industry = pd.concat([top5, others])

plt.figure(figsize=(8,8))

plt.pie(
    final_industry,
    labels=final_industry.index,
    autopct='%1.1f%%',
    startangle=90,
    wedgeprops={'width': 0.4}
)

plt.title("Top Industry Distribution")

plt.savefig(
    "../charts/industry_distribution.png",
    bbox_inches="tight"
)

plt.show()

# %%
# Salary Distribution

import re

def extract_salary(value):
    nums = re.findall(r'\d+', str(value).replace(',', ''))
    if len(nums) >= 2:
        return (int(nums[0]) + int(nums[1])) / 2
    elif len(nums) == 1:
        return int(nums[0])
    else:
        return None

df['salary_numeric'] = df['salary'].apply(extract_salary)

plt.figure(figsize=(10,5))
plt.hist(df['salary_numeric'].dropna(), bins=20)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Job Count")
plt.savefig("../charts/salary_distribution.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # BIVARIATE ANALYSIS
# #(Two variables analysis)

# %%
# Average Salary by Seniority

salary_by_seniority = df.groupby('seniority_level')['salary_numeric'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,5))
salary_by_seniority.plot(kind='bar')
plt.title("Average Salary by Seniority Level")
plt.xlabel("Seniority Level")
plt.ylabel("Average Salary")
plt.xticks(rotation=45, ha='right')
plt.savefig("../charts/avg_salary_by_seniority.png", bbox_inches="tight")
plt.show()

# %%
# Jobs by Industry

industry_jobs = df.groupby('industry')['job_title'].count().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))

industry_jobs.sort_values().plot(kind='barh')

plt.title("Top Industries Hiring")

plt.xlabel("Job Count")
plt.ylabel("Industry")

plt.savefig("../charts/top_industries_hiring.png")

plt.show()
